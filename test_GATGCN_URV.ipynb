# %% [markdown]
# ## train and test GAT GCN model on the URV database.

# %%
# train of GAT model on URV dataset
from URV_Train import Train
import models.gat_gcn as GATGCN

model = Train(dataset = 'urv', model_type = GATGCN.GAT_GCN(), cuda_name = "cuda:0", TRAIN_BATCH_SIZE = 8, TEST_BATCH_SIZE = 8, LR = 0.0005, NUM_EPOCHS = 50)
# Out:
# creating pytorch data.
# data/processed/urv_train.pt  and  data/processed/urv_test.pt  are already created
# pytorch data created.
# model_st: GAT_GCN
# cuda_name: cuda:0
#
# running on  GAT_GCN_urv
#
# running on dataset :  urv
# Pre-processed data found: data\processed\urv_train.pt, loading ...
# Pre-processed data found: data\processed\urv_test.pt, loading ...
# Training on 120 samples...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Train epoch: 1 [0/120 (0%)]	Loss: 34.817860
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 2 [0/120 (0%)]	Loss: 0.948711
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 3 [0/120 (0%)]	Loss: 0.638778
# predicting for valid data
# Make prediction for 31 samples...
# ...

# %%
# test of GCN model on URV dataset
from URV_Test import Test
import torch
import models.gat_gcn as GATGCN
# Create an instance of the model
model = GATGCN.GAT_GCN()

# Load the state dictionary from the file
model_file_name = 'model_GAT_GCN_urv.model'
state_dict = torch.load(model_file_name)

# Load the state dictionary into the model
model.load_state_dict(state_dict)

# Optionally, set the model to evaluation mode
model.eval()
test_mse = Test(model, dataset = 'urv', cuda_name = "cuda:0", TEST_BATCH_SIZE = 8 )
# Out:
# predicting for test data
# Pre-processed data found: data\processed\urv_test.pt, loading ...
# Make prediction for 151 samples...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %% [markdown]
# ## train and test GATGCN model on the URV database with n_folds = 10.

# %%
# train of GATGCN model on URV dataset with n_folds = 10
from URV_Train import Trainfold
import models.gat_gcn as GATGCN

model = Trainfold(dataset = 'urv', model_type = GATGCN.GAT_GCN(), cuda_name = "cuda:0", TRAIN_BATCH_SIZE = 8, TEST_BATCH_SIZE = 8, LR = 0.0005, NUM_EPOCHS = 50, n_folds = 10)
# Out:
# creating pytorch data.
# data/processed/urv_fold1_train.pt  and  data/processed/urv_fold1_test.pt  are already created
# pytorch data created.
# model_st: GAT_GCN
# cuda_name: cuda:0
#
# running on  GAT_GCN_urv_fold1
#
# running on dataset :  urv_fold1
# Pre-processed data found: data\processed\urv_fold1_train.pt, loading ...
# Pre-processed data found: data\processed\urv_fold1_test.pt, loading ...
# Training on 238 samples...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Train epoch: 1 [0/238 (0%)]	Loss: 28.903944
# Train epoch: 1 [3900/238 (67%)]	Loss: 1.273756
# predicting for valid data
# Make prediction for 60 samples...
# Training on 238 samples...
# Train epoch: 2 [0/238 (0%)]	Loss: 0.867139
# Train epoch: 2 [4080/238 (67%)]	Loss: 1.312103
# predicting for valid data
# Make prediction for 60 samples...
# ...

# %%
# test of GATGCN model on URV dataset with n_folds = 10
from URV_Test import Testfold
import models.gat_gcn as GATGCN

# Create an instance of the model
model = GATGCN.GAT_GCN()
dataset = 'urv'
cuda_name = "cuda:0"

test_mse_list = Testfold(model, dataset, cuda_name, TEST_BATCH_SIZE = 1, n_folds = 10)
# Out:
# predicting for test data
# Pre-processed data found: data\processed\urv_fold1_test.pt, loading ...
# Make prediction for 34 samples...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# predicting for test data
# Pre-processed data found: data\processed\urv_fold2_test.pt, loading ...
# Make prediction for 34 samples...
# predicting for test data
# Pre-processed data found: data\processed\urv_fold3_test.pt, loading ...
# Make prediction for 33 samples...
# predicting for test data
# Pre-processed data found: data\processed\urv_fold4_test.pt, loading ...
# Make prediction for 33 samples...
# predicting for test data
# Pre-processed data found: data\processed\urv_fold5_test.pt, loading ...
# Make prediction for 33 samples...
# predicting for test data
# Pre-processed data found: data\processed\urv_fold6_test.pt, loading ...
# ...

# %%
import numpy as np

mean = np.mean(test_mse_list)
std_dev = np.std(test_mse_list)
print(mean)
print(std_dev)
# Out:
# 0.44377866
# 0.23931067
