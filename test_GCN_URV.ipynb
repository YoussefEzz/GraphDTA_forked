# %% [markdown]
# ## train and test GCN model on the URV database.

# %%
# train of GCN model on URV dataset
from URV_Train import Train
import models.gcn as GCN

model = Train(dataset = 'urv', model_type = GCN.GCNNet(), cuda_name = "cuda:0", TRAIN_BATCH_SIZE = 8, TEST_BATCH_SIZE = 8, LR = 0.0005, NUM_EPOCHS = 50)
# Out:
# creating pytorch data.
# data/processed/urv_train.pt  and  data/processed/urv_test.pt  are already created
# pytorch data created.
# model_st: GCNNet
# cuda_name: cuda:0
#
# running on  GCNNet_urv
#
# running on dataset :  urv
# Pre-processed data found: data\processed\urv_train.pt, loading ...
# Pre-processed data found: data\processed\urv_test.pt, loading ...
# Training on 120 samples...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Train epoch: 1 [0/120 (0%)]	Loss: 28.798986
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 2 [0/120 (0%)]	Loss: 1.464481
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 3 [0/120 (0%)]	Loss: 0.835961
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 4 [0/120 (0%)]	Loss: 0.433240
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 5 [0/120 (0%)]	Loss: 3.993496
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 6 [0/120 (0%)]	Loss: 0.998322
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 7 [0/120 (0%)]	Loss: 1.860175
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 8 [0/120 (0%)]	Loss: 3.385335
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 9 [0/120 (0%)]	Loss: 1.228582
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 10 [0/120 (0%)]	Loss: 1.613236
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 11 [0/120 (0%)]	Loss: 0.639069
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 12 [0/120 (0%)]	Loss: 1.794930
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 13 [0/120 (0%)]	Loss: 0.385462
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 14 [0/120 (0%)]	Loss: 0.996312
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 15 [0/120 (0%)]	Loss: 1.675832
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 16 [0/120 (0%)]	Loss: 1.201526
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 17 [0/120 (0%)]	Loss: 1.849672
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 18 [0/120 (0%)]	Loss: 0.793493
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 19 [0/120 (0%)]	Loss: 1.250423
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 20 [0/120 (0%)]	Loss: 3.148711
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 21 [0/120 (0%)]	Loss: 3.233622
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 22 [0/120 (0%)]	Loss: 0.605026
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 23 [0/120 (0%)]	Loss: 1.706876
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 24 [0/120 (0%)]	Loss: 1.110309
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 25 [0/120 (0%)]	Loss: 0.897338
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 26 [0/120 (0%)]	Loss: 1.944867
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 27 [0/120 (0%)]	Loss: 1.516201
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 28 [0/120 (0%)]	Loss: 0.743161
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 29 [0/120 (0%)]	Loss: 0.372365
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 30 [0/120 (0%)]	Loss: 0.559691
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 31 [0/120 (0%)]	Loss: 0.160025
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 32 [0/120 (0%)]	Loss: 0.304787
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 33 [0/120 (0%)]	Loss: 0.440286
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 34 [0/120 (0%)]	Loss: 0.439876
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 35 [0/120 (0%)]	Loss: 0.248952
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 36 [0/120 (0%)]	Loss: 0.188161
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 37 [0/120 (0%)]	Loss: 0.654087
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 38 [0/120 (0%)]	Loss: 0.480584
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 39 [0/120 (0%)]	Loss: 0.866814
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 40 [0/120 (0%)]	Loss: 0.387715
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 41 [0/120 (0%)]	Loss: 0.543854
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 42 [0/120 (0%)]	Loss: 0.698176
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 43 [0/120 (0%)]	Loss: 0.616847
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 44 [0/120 (0%)]	Loss: 0.200635
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 45 [0/120 (0%)]	Loss: 0.592754
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 46 [0/120 (0%)]	Loss: 0.860341
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 47 [0/120 (0%)]	Loss: 0.334696
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 48 [0/120 (0%)]	Loss: 0.595577
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 49 [0/120 (0%)]	Loss: 0.751087
# predicting for valid data
# Make prediction for 31 samples...
# Training on 120 samples...
# Train epoch: 50 [0/120 (0%)]	Loss: 0.813607
# predicting for valid data
# Make prediction for 31 samples...
# GCNNet(
#   (conv1): GCNConv(78, 78)
#   (conv2): GCNConv(78, 156)
#   (conv3): GCNConv(156, 312)
#   (fc_g1): Linear(in_features=312, out_features=1024, bias=True)
#   (fc_g2): Linear(in_features=1024, out_features=128, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (embedding_xt): Embedding(26, 128)
#   (conv_xt_1): Conv1d(1000, 32, kernel_size=(8,), stride=(1,))
#   (fc1_xt): Linear(in_features=3872, out_features=128, bias=True)
#   (fc1): Linear(in_features=256, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (out): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
# test of GCN model on URV dataset
from URV_Test import Test
import torch
import models.gcn as GCN
# Create an instance of the model
model = GCN.GCNNet()

# Load the state dictionary from the file
model_file_name = 'model_GCNNet_urv.model'
state_dict = torch.load(model_file_name)

# Load the state dictionary into the model
model.load_state_dict(state_dict)

# Optionally, set the model to evaluation mode
model.eval()
test_mse = Test(model, dataset = 'urv', cuda_name = "cuda:0", TEST_BATCH_SIZE = 1 )
# Out:
# predicting for test data
# Pre-processed data found: data\processed\urv_test.pt, loading ...
# Make prediction for 151 samples...
