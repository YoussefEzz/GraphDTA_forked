# %% [markdown]
# ## train and test GIN CONV model on the URV database.

# %%
# train of GAT model on URV dataset
from URV_Train import Train
import models.ginconv as GINCONV

model = Train(dataset = 'urv', model_type = GINCONV.GINConvNet(), cuda_name = "cuda:0", TRAIN_BATCH_SIZE = 8, TEST_BATCH_SIZE = 8, LR = 0.0001, NUM_EPOCHS = 1000, validation_size=0.2)
# Out:
# creating pytorch data.
# preparing  urv_train.pt in pytorch format!
# Pre-processed data data/processed/urv_train.pt not found, doing pre-processing...
# Converting SMILES to graph: 1/298
# Converting SMILES to graph: 2/298
# Converting SMILES to graph: 3/298
# Converting SMILES to graph: 4/298
# Converting SMILES to graph: 5/298
# Converting SMILES to graph: 6/298
# Converting SMILES to graph: 7/298
# Converting SMILES to graph: 8/298
# Converting SMILES to graph: 9/298
# Converting SMILES to graph: 10/298
# Converting SMILES to graph: 11/298
# Converting SMILES to graph: 12/298
# Converting SMILES to graph: 13/298
# Converting SMILES to graph: 14/298
# Converting SMILES to graph: 15/298
# Converting SMILES to graph: 16/298
# Converting SMILES to graph: 17/298
# Converting SMILES to graph: 18/298
# Converting SMILES to graph: 19/298
# Converting SMILES to graph: 20/298
# Converting SMILES to graph: 21/298
# Converting SMILES to graph: 22/298
# Converting SMILES to graph: 23/298
# ...

# %%
# test of GCN model on URV dataset
from URV_Test import Test
import torch
import models.ginconv as GINCONV

# Create an instance of the model
model = GINCONV.GINConvNet()

# Load the state dictionary from the file
model_file_name = 'model_GINConvNet_urv.model'
state_dict = torch.load(model_file_name)

# Load the state dictionary into the model
model.load_state_dict(state_dict)

# Optionally, set the model to evaluation mode
model.eval()
test_mse = Test(model, dataset = 'urv', cuda_name = "cuda:0", TEST_BATCH_SIZE = 1)
# Out:
# /tmp/ipykernel_190732/1174630562.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_file_name)
# predicting for test data
# ...

# %% [markdown]
# ## train and test GINCONV model on the URV database with n_folds = 10.

# %%
# train of GINCONV model on URV dataset with n_folds = 10
from URV_Train import Trainfold
import models.ginconv as GINCONV

model = Trainfold(dataset = 'urv', model_type = GINCONV.GINConvNet(), cuda_name = "cuda:0", TRAIN_BATCH_SIZE = 8, TEST_BATCH_SIZE = 8, LR = 0.0005, NUM_EPOCHS = 50, n_folds = 10)
# Out:
# creating pytorch data.
# data/processed/urv_fold1_train.pt  and  data/processed/urv_fold1_test.pt  are already created
# pytorch data created.
# model_st: GINConvNet
# cuda_name: cuda:0
#
# running on  GINConvNet_urv_fold1
#
# running on dataset :  urv_fold1
# Pre-processed data found: data\processed\urv_fold1_train.pt, loading ...
# Pre-processed data found: data\processed\urv_fold1_test.pt, loading ...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Training on 238 samples...
# Train epoch: 1 [0/238 (0%)]	Loss: 29.968187
# Train epoch: 1 [3820/238 (67%)]	Loss: 0.810582
# predicting for valid data
# Make prediction for 60 samples...
# Training on 238 samples...
# Train epoch: 2 [0/238 (0%)]	Loss: 0.781688
# Train epoch: 2 [3740/238 (67%)]	Loss: 1.154415
# predicting for valid data
# Make prediction for 60 samples...
# ...

# %%
# test of GINCONV model on URV dataset with n_folds = 10
from URV_Test import Testfold
import models.ginconv as GINCONV

# Create an instance of the model
model = GINCONV.GINConvNet()
dataset = 'urv'
cuda_name = "cuda:0"

test_mse_list = Testfold(model, dataset, cuda_name, TEST_BATCH_SIZE = 1, n_folds = 10)
# Out:
# predicting for test data
# Pre-processed data found: data\processed\urv_fold1_test.pt, loading ...
# Make prediction for 34 samples...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# predicting for test data
# Pre-processed data found: data\processed\urv_fold2_test.pt, loading ...
# Make prediction for 34 samples...
# predicting for test data
# Pre-processed data found: data\processed\urv_fold3_test.pt, loading ...
# Make prediction for 33 samples...
# predicting for test data
# Pre-processed data found: data\processed\urv_fold4_test.pt, loading ...
# Make prediction for 33 samples...
# predicting for test data
# Pre-processed data found: data\processed\urv_fold5_test.pt, loading ...
# Make prediction for 33 samples...
# predicting for test data
# Pre-processed data found: data\processed\urv_fold6_test.pt, loading ...
# ...

# %%
import numpy as np

mean = np.mean(test_mse_list)
std_dev = np.std(test_mse_list)
print(mean)
print(std_dev)
# Out:
# 0.75991523
# 0.5566399

# %%
# train of GAT model on URV dataset
from URV_Train import Train
import models.ginconv as GINCONV

model = Train(dataset = 'urv', model_type = GINCONV.GINConvNet(), cuda_name = "cuda:0", TRAIN_BATCH_SIZE = 8, TEST_BATCH_SIZE = 8, LR = 0.0005, NUM_EPOCHS = 50)
# Out:
# creating pytorch data.
# preparing  urv_train.pt in pytorch format!
# Pre-processed data data/processed/urv_train.pt not found, doing pre-processing...
# Converting SMILES to graph: 1/298
# Converting SMILES to graph: 2/298
# Converting SMILES to graph: 3/298
# Converting SMILES to graph: 4/298
# Converting SMILES to graph: 5/298
# Converting SMILES to graph: 6/298
# Converting SMILES to graph: 7/298
# Converting SMILES to graph: 8/298
# Converting SMILES to graph: 9/298
# Converting SMILES to graph: 10/298
# Converting SMILES to graph: 11/298
# Converting SMILES to graph: 12/298
# Converting SMILES to graph: 13/298
# Converting SMILES to graph: 14/298
# Converting SMILES to graph: 15/298
# Converting SMILES to graph: 16/298
# Converting SMILES to graph: 17/298
# Converting SMILES to graph: 18/298
# Converting SMILES to graph: 19/298
# Converting SMILES to graph: 20/298
# Converting SMILES to graph: 21/298
# Converting SMILES to graph: 22/298
# Converting SMILES to graph: 23/298
# ...
