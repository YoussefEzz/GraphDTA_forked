# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

davis_datapath = "data"
davis_train_filepath = davis_datapath + '/davis_train.csv'
davis_test_filepath = davis_datapath + '/davis_test.csv'

# Read the train Affinity TXT file into a dataframe
train_dataframe = pd.read_csv(davis_train_filepath,sep=r',')  # Use the appropriate delimiter if your file is not tab-separated

# Read the train TXT file into a dataframe
test_dataframe = pd.read_csv(davis_test_filepath,sep=r',')  # Use the appropriate delimiter if your file is not tab-separated

# column_names = train_dataframe.columns.tolist()
# print(column_names)


# Select the train smiles column
train_smiles = train_dataframe.iloc[:, 0]
print(len(train_smiles))

# Select the test smiles column
test_smiles = test_dataframe.iloc[:, 0]
print(len(test_smiles))

# Concatenate the train and test smiles columns
smiles = pd.concat([train_smiles, test_smiles], ignore_index=True)
smiles_lengths = [len(smile) for smile in smiles]
print(len(smiles))


# Select the train protein sequence column
train_protein = train_dataframe.iloc[:, 1]
print(len(train_protein))

# Select the test smiles column
test_protein = test_dataframe.iloc[:, 1]
print(len(test_protein))

# Concatenate the train and test smiles columns
proteins = pd.concat([train_protein, test_protein], ignore_index=True)
proteins_lengths = [len(protein) for protein in proteins]
print(len(proteins))


# Select the train affinity column
train_affinity = train_dataframe.iloc[:, 2]
print(len(train_affinity))

# Select the test affinity column
test_affinity = test_dataframe.iloc[:, 2]
print(len(test_affinity))

# Concatenate the train and test affinity columns
affinity = pd.concat([train_affinity, test_affinity], ignore_index=True)
print(len(affinity))
# Out:
# 25046
# 5010
# 30056
# 25046
# 5010
# 30056
# 25046
# 5010
# 30056

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Sample data
np.random.seed(10)
data = affinity
print(data)

# Create a boxplot
sns.boxplot(data=data, width = 0.07, fill= False)

# Add the points
# For visual clarity, jitter the points along the x-axis
x = np.random.normal(0, 0.01, size=len(data)) # add some jitter
plt.scatter(x, data, color='red', alpha=0.6)

# Set labels and title
plt.xlabel(f'(size = {len(affinity)}), jitter = {0.01}')
plt.ylabel('affinity')
plt.title('Box Plot for Drug Protein affinity pKd with jitter = 0.01')

# Show plot
plt.show()
# Out:
# 0        5.000000
# 1        5.000000
# 2        5.000000
# 3        5.000000
# 4        5.000000
#            ...
# 30051    6.677781
# 30052    5.000000
# 30053    5.000000
# 30054    5.000000
# 30055    5.000000
# Name: affinity, Length: 30056, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
np.random.seed(10)
data = np.random.normal(size=1000)

# Create histogram
plt.hist(affinity, bins=30, alpha=0.7, color='blue', edgecolor='black')

# Add title and labels
plt.title('Histogram of davis pKd Affinity bins')
plt.xlabel('pKd')
plt.ylabel('Frequency')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
np.random.seed(10)
data = np.random.normal(size=1000)

# Create histogram
n, bins, patches = plt.hist(smiles_lengths, bins=30, alpha=0.7, color='blue', edgecolor='black')

# Add title and labels
plt.title('Histogram of SMILES length bins of davis dataset')
plt.xlabel('SMILES length(chars)')
plt.ylabel('Number of DTA pairs')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
np.random.seed(10)
data = np.random.normal(size=1000)

# Create histogram
plt.hist(proteins_lengths, bins=30, alpha=0.7, color='blue', edgecolor='black')

# Add title and labels
plt.title('Histogram of Protein length bins of davis dataset')
plt.xlabel('protein sequence length(chars)')
plt.ylabel('Number of DTA pairs')

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of Kd values
Kd_range = np.linspace(1, 10000)

# Calculate the pkd values
pkd = -np.log10(Kd_range / 1e9)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(Kd_range, pkd)

# Set the x-axis scale to logarithmic
ax.set_xscale('log')

# Set the axis labels and title
ax.set_xlabel('Kd in nanoMolar')
ax.set_ylabel('pkd')
ax.set_title('Plot of pkd = -log_10 (Kd/1e9)')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of Kd values
Kd_range = np.logspace(1, 10000)

# Calculate the pkd values
pkd = -np.log10(Kd_range / 1e9)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(Kd_range, pkd)

# Set the x-axis scale to logarithmic
#ax.set_xscale('log')

# Set the axis labels and title
ax.set_xlabel('Kd in nanoMolar')
ax.set_ylabel('pkd')
ax.set_title('Plot of pkd = -log_10 (Kd/1e9)')

# Show the plot
plt.show()
# Out:
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\function_base.py:284: RuntimeWarning: overflow encountered in power
#   return _nx.power(base, y)
