# %% [markdown]
# ## test GCN model trained with davis database on the URV database.

# %%
# test of GATGCN model on URV dataset
import sys
import os

from URV_Train import Train

import models.gcn as GCN

model = Train(dataset = 'davis', model_type = GCN.GCNNet(), cuda_name = "cuda:0", TRAIN_BATCH_SIZE = 512, TEST_BATCH_SIZE = 512, LR = 0.0005, NUM_EPOCHS = 10)
# Out:
# creating pytorch data.
# data/processed/davis_train.pt  and  data/processed/davis_test.pt  are already created
# pytorch data created.
# model_st: GCNNet
# cuda_name: cuda:0
#
# running on  GCNNet_davis
#
# running on dataset :  davis
# Pre-processed data found: data\processed\davis_train.pt, loading ...
# Pre-processed data found: data\processed\davis_test.pt, loading ...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Training on 20036 samples...
# Train epoch: 1 [0/20036 (0%)]	Loss: 30.342957
# Train epoch: 1 [327960/20036 (50%)]	Loss: 1.534876
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 2 [0/20036 (0%)]	Loss: 0.869180
# Train epoch: 2 [332600/20036 (50%)]	Loss: 1.122688
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 3 [0/20036 (0%)]	Loss: 0.784675
# Train epoch: 3 [327400/20036 (50%)]	Loss: 0.725177
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 4 [0/20036 (0%)]	Loss: 0.914571
# Train epoch: 4 [330900/20036 (50%)]	Loss: 0.848169
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 5 [0/20036 (0%)]	Loss: 0.717709
# Train epoch: 5 [327240/20036 (50%)]	Loss: 0.525396
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 6 [0/20036 (0%)]	Loss: 0.824049
# Train epoch: 6 [325480/20036 (50%)]	Loss: 0.676019
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 7 [0/20036 (0%)]	Loss: 0.452039
# Train epoch: 7 [327740/20036 (50%)]	Loss: 0.569443
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 8 [0/20036 (0%)]	Loss: 0.597018
# Train epoch: 8 [331560/20036 (50%)]	Loss: 0.721568
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 9 [0/20036 (0%)]	Loss: 0.594472
# Train epoch: 9 [327300/20036 (50%)]	Loss: 0.804644
# predicting for valid data
# Make prediction for 5010 samples...
# Training on 20036 samples...
# Train epoch: 10 [0/20036 (0%)]	Loss: 0.678370
# Train epoch: 10 [332660/20036 (50%)]	Loss: 0.676797
# predicting for valid data
# Make prediction for 5010 samples...
# GCNNet(
#   (conv1): GCNConv(78, 78)
#   (conv2): GCNConv(78, 156)
#   (conv3): GCNConv(156, 312)
#   (fc_g1): Linear(in_features=312, out_features=1024, bias=True)
#   (fc_g2): Linear(in_features=1024, out_features=128, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (embedding_xt): Embedding(26, 128)
#   (conv_xt_1): Conv1d(1000, 32, kernel_size=(8,), stride=(1,))
#   (fc1_xt): Linear(in_features=3872, out_features=128, bias=True)
#   (fc1): Linear(in_features=256, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (out): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
# test of GCN model on URV dataset
from URV_Test import Test
import torch
import models.gcn as GCN

# Create an instance of the model
model = GCN.GCNNet()

# Load the state dictionary from the file
model_file_name = 'model_GCNNet_davis.model'
state_dict = torch.load(model_file_name)

# Load the state dictionary into the model
model.load_state_dict(state_dict)

# Optionally, set the model to evaluation mode
model.eval()
test_mse = Test(model, dataset = 'urv', cuda_name = "cuda:0", TEST_BATCH_SIZE = 8 )
# Out:
# predicting for test data
# Pre-processed data found: data\processed\urv_test.pt, loading ...
# Make prediction for 151 samples...
# c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
